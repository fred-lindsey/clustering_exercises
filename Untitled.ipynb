# %%
import warnings
warnings.filterwarnings("ignore")

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from scipy import stats
import env
import os
import sklearn.preprocessing
from sklearn.model_selection import train_test_split
import wrangle
# reloads import files each time a cell is ran
# %load_ext autoreload
# %autoreload 2

# %%
df = wrangle.get_zillow_data()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77614 entries, 0 to 77613
# Data columns (total 65 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   typeconstructiontypeid        223 non-null    float64
#  1   storytypeid                   50 non-null     float64
#  2   propertylandusetypeid         77580 non-null  float64
#  3   parcelid                      77614 non-null  int64
#  4   id                            77614 non-null  int64
#  5   logerror                      77614 non-null  float64
#  6   transactiondate               77614 non-null  object
#  7   id.1                          77614 non-null  int64
#  8   airconditioningtypeid         25007 non-null  float64
#  9   architecturalstyletypeid      207 non-null    float64
#  10  basementsqft                  50 non-null     float64
#  11  bathroomcnt                   77580 non-null  float64
# ...

# %%
df.isna().mean().sort_values(ascending=True).head(60)
# Out:
# parcelid                        0.000000
# id                              0.000000
# logerror                        0.000000
# transactiondate                 0.000000
# id.1                            0.000000
# longitude                       0.000438
# propertycountylandusecode       0.000438
# rawcensustractandblock          0.000438
# regionidcounty                  0.000438
# bedroomcnt                      0.000438
# bathroomcnt                     0.000438
# roomcnt                         0.000438
# latitude                        0.000438
# assessmentyear                  0.000438
# propertylandusetypeid           0.000438
# propertylandusedesc             0.000438
# fips                            0.000438
# taxvaluedollarcnt               0.000451
# landtaxvaluedollarcnt           0.000464
# taxamount                       0.000502
# regionidzip                     0.001082
# structuretaxvaluedollarcnt      0.001920
# calculatedfinishedsquarefeet    0.003028
# ...

# %%
# I'm comfortable dropping columns with more than 30% null values
(df.isna().mean()>0.30).sort_values(ascending=False).head(60)
# Out:
# typeconstructiontypeid         True
# propertyzoningdesc             True
# garagetotalsqft                True
# hashottuborspa                 True
# heatingorsystemtypeid          True
# storytypeid                    True
# poolcnt                        True
# poolsizesum                    True
# pooltypeid10                   True
# pooltypeid2                    True
# pooltypeid7                    True
# regionidneighborhood           True
# fireplacecnt                   True
# threequarterbathnbr            True
# unitcnt                        True
# yardbuildingsqft17             True
# yardbuildingsqft26             True
# numberofstories                True
# fireplaceflag                  True
# taxdelinquencyflag             True
# taxdelinquencyyear             True
# storydesc                      True
# garagecarcnt                   True
# typeconstructiondesc           True
# buildingqualitytypeid          True
# finishedfloor1squarefeet       True
# ...

# %%
# I'm comfortable dropping columns with more than 30% null values
(df.isna().mean()>0.30)
# Out:
# typeconstructiontypeid     True
# storytypeid                True
# propertylandusetypeid     False
# parcelid                  False
# id                        False
#                           ...
# taxdelinquencyyear         True
# censustractandblock       False
# propertylandusedesc       False
# storydesc                  True
# typeconstructiondesc       True
# Length: 65, dtype: bool

# %%
df.describe().T
# Out:
#                                 count          mean           std  \
# typeconstructiontypeid          223.0  6.040359e+00  5.560348e-01
# storytypeid                      50.0  7.000000e+00  0.000000e+00
# propertylandusetypeid         77580.0  2.618245e+02  5.141564e+00
# parcelid                      77614.0  1.300781e+07  3.518694e+06
# id                            77614.0  3.880650e+04  2.240538e+04
# logerror                      77614.0  1.675218e-02  1.708879e-01
# id.1                          77614.0  1.496056e+06  8.613448e+05
# airconditioningtypeid         25007.0  1.812013e+00  2.965768e+00
# architecturalstyletypeid        207.0  7.386473e+00  2.728030e+00
# basementsqft                     50.0  6.797200e+02  6.897035e+02
# bathroomcnt                   77580.0  2.298492e+00  9.967259e-01
# bedroomcnt                    77580.0  3.053222e+00  1.140472e+00
# buildingclasstypeid              15.0  3.933333e+00  2.581989e-01
# ...

# %%
df = wrangle.wrangle_zillow()
df.head()
